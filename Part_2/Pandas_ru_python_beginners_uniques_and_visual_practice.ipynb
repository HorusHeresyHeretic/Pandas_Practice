# %%
from __future__ import (absolute_import, division,
                        print_function, unicode_literals)
import warnings
warnings.simplefilter('ignore')
import pandas as pd
import numpy as pr
df = pd.read_csv("C:/Users/Battlestation/Downloads/chat.csv")

# %%
df.head()
# Out:
#                  Name Activity  Messages  Active days  Flood ratio
# 0                Zart    9.59%      1864           32          116
# 1               b0g3r    5.95%      1537           31           91
# 2            in favor    3.32%       630           29          100
# 3  Aleksandr Biryukov    3.11%       555            5          138
# 4         Robert Ford    2.91%       229           23          131

# %%
df
# Out:
#                                                   Name   Activity  Messages  \
# 0                                                 Zart      9.59%      1864
# 1                                                b0g3r      5.95%      1537
# 2                                             in favor      3.32%       630
# 3                                   Aleksandr Biryukov      3.11%       555
# 4                                          Robert Ford      2.91%       229
# 5                                Sadness is everything      2.67%       251
# 6                                              Маришка      2.22%       572
# 7                                     Pavel Zagrebelin      2.06%       290
# 8                                               Sergey         2%       419
# 9                                             Eugene P      1.97%       240
# 10                                    Dmitry Bubnenkov      1.86%       295
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 5 columns):
# Name           499 non-null object
# Activity       499 non-null object
# Messages       499 non-null int64
# Active days    499 non-null int64
# Flood ratio    499 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 19.6+ KB

# %%
df.describe()
# Out:
#           Messages  Active days  Flood ratio
# count   499.000000   499.000000   499.000000
# mean     36.891784     3.871743   131.949900
# std     127.722592     5.321735    99.336269
# min       1.000000     1.000000    13.000000
# 25%       3.000000     1.000000    72.000000
# 50%       7.000000     2.000000   103.000000
# 75%      24.000000     4.000000   153.000000
# max    1864.000000    32.000000   597.000000

# %%
df.describe(include=['object'])
# Out:
#                  Name  Activity
# count             499       499
# unique            481       402
# top     [hidden user]  0.00204%
# freq                5        10

# %%
df.index
# Out:
# RangeIndex(start=0, stop=499, step=1)

# %%
df.loc[0]
# Out:
# Name            Zart
# Activity       9.59%
# Messages        1864
# Active days       32
# Flood ratio      116
# Name: 0, dtype: object

# %%
df.apply(pr.max)
# Out:
# Name               🤔
# Activity       9.59%
# Messages        1864
# Active days       32
# Flood ratio      597
# dtype: object

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker
# %matplotlib inline

# настройка внешнего вида графиков в seaborn
sns.set_context(
    "notebook", 
    font_scale = 1.5,       
    rc = { 
        "figure.figsize" : (12, 9), 
        "axes.titlesize" : 18 
    }
)

# %%
df_uniques = pd.melt(frame=df, value_vars=['Messages','Active days', 
                                                 'Flood ratio'])


df_uniques = pd.DataFrame(df_uniques.groupby(['variable', 
                                                    'value'])['value'].count()) \
    .sort_index(level=[0, 1]) \
    .rename(columns={'value': 'count'}) \
    .reset_index()
    
sns.factorplot(x='variable', y='count', hue='variable', 
               data=df_uniques, kind='bar', size=12);

# %%
df_uniques = pd.melt(frame=df, value_vars=['Messages','Active days', 
                                                 'Flood ratio'])


df_uniques = pd.DataFrame(df_uniques.groupby(['variable', 
                                                    'value'])['value'].count()) \
    .sort_index(level=[0, 1]) \
    .rename(columns={'value': 'count'}) \
    .reset_index()
    
sns.factorplot(x='variable', y='value', hue='variable', 
               data=df_uniques, kind='bar', size=12);

# %%
df_uniques = pd.melt(frame=df, value_vars=['Messages','Active days', 
                                                 'Flood ratio'])


df_uniques = pd.DataFrame(df_uniques.groupby(['variable', 
                                                    'value'])['value'].count()) \
    .sort_index(level=[0, 1]) \
    .rename(columns={'value': 'count'}) \
    .reset_index()
    
sns.factorplot(x='variable', y='count', hue='count', 
               data=df_uniques, kind='bar', size=12);

# %%
df = pd.read_csv("C:/Users/Battlestation/Downloads/chat.csv")

# %%
corr = df.corr(method='pearson')

# Генерируем маску для отсечения верхней диагонали матрицы
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(12, 9))

sns.heatmap(corr, mask=mask, vmax=1, center=0, annot=True, fmt='.1f',
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

# %%
X = df

# %%
X['Name'] = pd.factorize(X['Name'])[0]
X['Activity'] = pd.factorize(X['Activity'])[0]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
tsne = TSNE(random_state=17)
tsne_representation = tsne.fit_transform(X_scaled)

# %%
plt.scatter(tsne_representation[:, 0], tsne_representation[:, 1]);

# %%
import numpy as np;data = np.array(values).astype('float32')

# %%
values
# Out:
# [[1, 4], [2, 4]]

# %%
import numpy as np

# %%
values = np.array(values).astype('float64')

# %%
values
# Out:
# array([[ 1.,  4.],
#        [ 2.,  4.]])

# %%
values = [[1,4], [2,4]]

# %%
import numpy as np; values = np.array(values).astype('float64')

# %%
values
# Out:
# array([[ 1.,  4.],
#        [ 2.,  4.]])
