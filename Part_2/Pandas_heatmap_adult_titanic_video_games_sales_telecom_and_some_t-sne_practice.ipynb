# %%
from __future__ import (absolute_import, division,
                        print_function, unicode_literals)
import warnings
warnings.simplefilter('ignore')
# будем отображать графики прямо в jupyter'e
# %pylab inline                 
# увеличим дефолтный размер графиков
from pylab import rcParams    
rcParams['figure.figsize'] = 18, 15
import pandas as pd
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("J:/HiEnd/mlcourse_open-master/mlcourse_open-master/data/adult.data.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# salary            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None

# %%
# стоит от метить что хит мапы через сводные таблицы умеют рабоать с object ,а вот всё что выше - почти всегда хочет цифру.
rcParams['figure.figsize'] = 20, 15
heat_map_native_country = data.pivot_table(
                        index='native-country', 
                        columns='workclass', 
                        values='hours-per-week', 
                        aggfunc=sum).fillna(0).applymap(float)
sns.heatmap(heat_map_native_country, annot=True, fmt=".1f", linewidths=.5)

# %%
rcParams['figure.figsize'] = 20, 15
heat_map_native_country_sex = data.pivot_table(
                        index='native-country', 
                        columns='sex', 
                        values='hours-per-week', 
                        aggfunc=sum).fillna(0).applymap(float)
sns.heatmap(heat_map_native_country_sex, annot=True, fmt=".1f", linewidths=.5)

# %%
df = pd.read_csv("J:/HiEnd/mlcourse_open-master/mlcourse_open-master/data/telecom_churn.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
# State                     3333 non-null object
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null object
# Voice mail plan           3333 non-null object
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total day charge          3333 non-null float64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total eve charge          3333 non-null float64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total night charge        3333 non-null float64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Total intl charge         3333 non-null float64
# ...

# %%
rcParams['figure.figsize'] = 20, 15
heat_map_state = df.pivot_table(
                        index='State', 
                        columns='Churn', 
                        values='Customer service calls', 
                        aggfunc=sum).fillna(0).applymap(float)
sns.heatmap(heat_map_state, annot=True, fmt=".1f", linewidths=.5)

# %%
rcParams['figure.figsize'] = 20, 15
heat_map_state_voice = df.pivot_table(
                        index='State', 
                        columns='Voice mail plan', 
                        values='Customer service calls', 
                        aggfunc=sum).fillna(0).applymap(float)
sns.heatmap(heat_map_state_voice, annot=True, fmt=".1f", linewidths=.5)

# %%
rcParams['figure.figsize'] = 20, 15
heat_map_state_voice_area = df.pivot_table(
                        index='State', 
                        columns='Area code', 
                        values='Customer service calls', 
                        aggfunc=sum).fillna(0).applymap(float)
sns.heatmap(heat_map_state_voice_area, annot=True, fmt=".1f", linewidths=.5)

# %%
df = pd.read_csv("C:/Users/Battlestation/Documents/Visual Studio 2015/Projects/PythonApplication1/PythonApplication1/titanic.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313 entries, 0 to 1312
# Data columns (total 7 columns):
# PassengerID    1313 non-null int64
# Name           1313 non-null object
# PClass         1313 non-null object
# Age            756 non-null float64
# Sex            1313 non-null object
# Survived       1313 non-null int64
# SexCode        1313 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 71.9+ KB

# %%
# не забывай - как датафрейм обзовёшь, так он и поедет, если вначале df = pd.read_csv то и внутри должен быть df.
rcParams['figure.figsize'] = 20, 15
heat_map_sex_survived = df.pivot_table(
                        index='PClass', 
                        columns='Survived', 
                        values='SexCode', 
                        aggfunc=sum).fillna(0).applymap(float)
sns.heatmap(heat_map_sex_survived, annot=True, fmt=".1f", linewidths=.5)

# %%
rcParams['figure.figsize'] = 20, 15
heat_map_age_survived = df.pivot_table(
                        index='PClass', 
                        columns='Survived', 
                        values='Age', 
                        aggfunc=sum).fillna(0).applymap(float)
sns.heatmap(heat_map_age_survived, annot=True, fmt=".1f", linewidths=.5)

# %%
rcParams['figure.figsize'] = 20, 15
heat_map_mix = df.pivot_table(
                        index='PClass', 
                        columns='Age', 
                        values='Survived', 
                        aggfunc=sum).fillna(0).applymap(float)
sns.heatmap(heat_map_mix, annot=True, fmt=".1f", linewidths=.5)

# %%
rcParams['figure.figsize'] = 20, 15
heat_map_state_voice_area = df.pivot_table(
                        index='Age', 
                        columns='PClass', 
                        values='Survived', 
                        aggfunc=sum).fillna(0).applymap(float)
sns.heatmap(heat_map_state_voice_area, annot=True, fmt=".1f", linewidths=.5)

# %%
rcParams['figure.figsize'] = 20, 15
heat_map_mix_mix = df.pivot_table(
                        index='Age', 
                        columns='PClass', 
                        values='SexCode', 
                        aggfunc=sum).fillna(0).applymap(float)
sns.heatmap(heat_map_mix_mix, annot=True, fmt=".1f", linewidths=.5)

# %%
df = pd.read_csv("J:/HiEnd/mlcourse_open-master/mlcourse_open-master/data/video_games_sales.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         10015 non-null object
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
df = df.dropna()
heat_map_sales = df.pivot_table(
                        index='Platform', 
                        columns='Genre', 
                        values='Global_Sales', 
                        aggfunc=sum).fillna(0).applymap(float)
sns.heatmap(heat_map_sales, annot=True, fmt=".1f", linewidths=.5)

# %%
heat_map_critic = df.pivot_table(
                        index='Year_of_Release', 
                        columns='Genre', 
                        values='Critic_Score', 
                        aggfunc=sum).fillna(0).applymap(float)
sns.heatmap(heat_map_critic, annot=True, fmt=".1f", linewidths=.5)

# %%
heat_map_time_sales = df.pivot_table(
                        index='Year_of_Release', 
                        columns='Genre', 
                        values='NA_Sales', 
                        aggfunc=sum).fillna(0).applymap(float)
sns.heatmap(heat_map_time_sales, annot=True, fmt=".1f", linewidths=.5)

# %%
df = pd.read_csv('J:/HiEnd/mlcourse_open-master (2)/mlcourse_open-master/data/mlbootcamp5_train.csv', sep=';', 
                 index_col='id')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70000 entries, 0 to 99999
# Data columns (total 12 columns):
# age            70000 non-null int64
# gender         70000 non-null int64
# height         70000 non-null int64
# weight         70000 non-null float64
# ap_hi          70000 non-null int64
# ap_lo          70000 non-null int64
# cholesterol    70000 non-null int64
# gluc           70000 non-null int64
# smoke          70000 non-null int64
# alco           70000 non-null int64
# active         70000 non-null int64
# cardio         70000 non-null int64
# dtypes: float64(1), int64(11)
# memory usage: 6.9 MB

# %%
df.head()
# Out:
#       age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# id
# 0   18393       2     168    62.0    110     80            1     1      0
# 1   20228       1     156    85.0    140     90            3     1      0
# 2   18857       1     165    64.0    130     70            3     1      0
# 3   17623       2     169    82.0    150    100            1     1      0
# 4   17474       1     156    56.0    100     60            1     1      0
#
#     alco  active  cardio
# id
# 0      0       1       0
# 1      0       1       1
# 2      0       0       1
# 3      0       1       1
# 4      0       0       0

# %%
rcParams['figure.figsize'] = 20, 15
heat_map_first_look= df.pivot_table(
                        index='height', 
                        columns='gender', 
                        values='weight', 
                        aggfunc=sum).fillna(0).applymap(float)
sns.heatmap(heat_map_first_look, annot=True, fmt=".1f", linewidths=.5)

# %%
rcParams['figure.figsize'] = 20, 15
heat_map_smoke_hi= df.pivot_table(
                        index='height', 
                        columns='smoke', 
                        values='gender', 
                        aggfunc=max).fillna(0).applymap(float)
sns.heatmap(heat_map_smoke_hi, annot=True, fmt=".1f", linewidths=.5)

# %%
rcParams['figure.figsize'] = 50, 35
heat_map_smoke_hi= df.pivot_table(
                        index='ap_hi', 
                        columns='ap_lo', 
                        values='smoke', 
                        ).fillna(0).applymap(float)
sns.heatmap(heat_map_smoke_hi, annot=True, fmt=".1f", linewidths=.5)

# %%
df = pd.read_csv("J:/HiEnd/mlcourse_open-master/mlcourse_open-master/data/adult.data.csv")
corr_matrix = df.corr()
sns.heatmap(corr_matrix);

# %%
rcParams['figure.figsize'] = 20, 15
corr_matrix = df.drop(['age'], axis=1).corr()
sns.heatmap(corr_matrix);

# %%
df = pd.read_csv("J:/HiEnd/mlcourse_open-master/mlcourse_open-master/data/telecom_churn.csv")
corr_matrix = df.corr()
sns.heatmap(corr_matrix);

# %%
corr_matrix = df.drop(['Area code'], axis=1).corr()
sns.heatmap(corr_matrix);

# %%
df = pd.read_csv("C:/Users/Battlestation/Documents/Visual Studio 2015/Projects/PythonApplication1/PythonApplication1/titanic.csv")
corr_matrix = df.corr()
sns.heatmap(corr_matrix);

# %%
df = pd.read_csv("J:/HiEnd/mlcourse_open-master/mlcourse_open-master/data/video_games_sales.csv")
corr_matrix = df.corr()
sns.heatmap(corr_matrix);

# %%
df = pd.read_csv('J:/HiEnd/mlcourse_open-master (2)/mlcourse_open-master/data/mlbootcamp5_train.csv', sep=';', 
                 index_col='id')
corr_matrix = df.corr()
sns.heatmap(corr_matrix);

# %%
corr_matrix = df.drop(['ap_lo', 'ap_hi'], axis=1).corr()
sns.heatmap(corr_matrix);

# %%
corr_matrix = df.drop(['ap_lo', 'ap_hi', 'age'], axis=1).corr()
sns.heatmap(corr_matrix);

# %%
df = pd.read_csv("J:/HiEnd/mlcourse_open-master/mlcourse_open-master/data/telecom_churn.csv")

# %%
X = df.drop(['Churn', 'State'], axis=1)
X['International plan'] = pd.factorize(X['International plan'])[0]
X['Voice mail plan'] = pd.factorize(X['Voice mail plan'])[0]

# В части, касающейся tsne, в коде: необходимо добавить sort = True чтобы факторизация признаков прошла одинаково
# Иначе Yes и No в разных колонках будут факторизованы как (1,0) и (0,1) соответственно,
# что приведет к невозможности в дальнейшем использовать их для обработки

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# достаточно долгая операция
# %timeit 
tsne = TSNE(random_state=17)
tsne_representation = tsne.fit_transform(X_scaled)

# %%
plt.scatter(tsne_representation[:, 0], tsne_representation[:, 1]);

# %%
df = pd.read_csv("C:/Users/Battlestation/Documents/Visual Studio 2015/Projects/PythonApplication1/PythonApplication1/titanic.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313 entries, 0 to 1312
# Data columns (total 7 columns):
# PassengerID    1313 non-null int64
# Name           1313 non-null object
# PClass         1313 non-null object
# Age            756 non-null float64
# Sex            1313 non-null object
# Survived       1313 non-null int64
# SexCode        1313 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 71.9+ KB

# %%
X = df.drop(['Name', 'Sex', 'PClass'], axis=1)
X['Survived'] = pd.factorize(X['Survived'])[0]
X['Age'] = pd.factorize(X['Age'])[0]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# %timeit a = list(range(100000)); b = list(range(100000))
tsne = TSNE(random_state=17)
tsne_representation = tsne.fit_transform(X_scaled)
# Out:
# 5.02 ms ± 429 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
plt.scatter(tsne_representation[:, 0], tsne_representation[:, 1]);

# %%
plt.scatter(tsne_representation[:, 0], tsne_representation[:, 1], 
            c=df['Survived'].map({0: 'blue', 1: 'orange'}));

# %%
df = pd.read_csv('J:/HiEnd/mlcourse_open-master (2)/mlcourse_open-master/data/mlbootcamp5_train.csv', sep=';', 
                 index_col='id')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70000 entries, 0 to 99999
# Data columns (total 12 columns):
# age            70000 non-null int64
# gender         70000 non-null int64
# height         70000 non-null int64
# weight         70000 non-null float64
# ap_hi          70000 non-null int64
# ap_lo          70000 non-null int64
# cholesterol    70000 non-null int64
# gluc           70000 non-null int64
# smoke          70000 non-null int64
# alco           70000 non-null int64
# active         70000 non-null int64
# cardio         70000 non-null int64
# dtypes: float64(1), int64(11)
# memory usage: 6.9 MB

# %%
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("J:/HiEnd/mlcourse_open-master/mlcourse_open-master/data/video_games_sales.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         10015 non-null object
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
df = df.dropna()
X = df.drop(['Name', 'Platform','Genre', 'Publisher', 'User_Score', 'Developer', 'Rating'], axis=1)
X['Year_of_Release'] = pd.factorize(X['Year_of_Release'], sort = True)[0]
X['NA_Sales'] = pd.factorize(X['NA_Sales'], sort = True)[0]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# %timeit a = list(range(100000)); b = list(range(100000))
tsne = TSNE(random_state=11)
tsne_representation = tsne.fit_transform(X_scaled)
# Out:
# 4.77 ms ± 66.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
plt.scatter(tsne_representation[:, 0], tsne_representation[:, 1]);

# %%
X = df.drop(['Name', 'Platform','Genre', 'Publisher', 'User_Score', 'Developer', 'Rating'], axis=1)
X['NA_Sales'] = pd.factorize(X['NA_Sales'], sort = True)[0]
X['Year_of_Release'] = pd.factorize(X['Year_of_Release'], sort = True)[0]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# %timeit a = list(range(100000)); b = list(range(100000))
tsne = TSNE(random_state=11)
tsne_representation = tsne.fit_transform(X_scaled)
# Out:
# 5.06 ms ± 142 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
plt.scatter(tsne_representation[:, 0], tsne_representation[:, 1]);

# %%
X = df.drop(['Name', 'Platform','Genre', 'Publisher', 'Developer', 'Rating'], axis=1)
X['Year_of_Release'] = pd.factorize(X['Year_of_Release'], sort = True)[0]
X['NA_Sales'] = pd.factorize(X['NA_Sales'], sort = True)[0]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# %timeit a = list(range(100000)); b = list(range(100000))
tsne = TSNE(random_state=11)
tsne_representation = tsne.fit_transform(X_scaled)
# Out:
# 5 ms ± 223 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
plt.scatter(tsne_representation[:, 0], tsne_representation[:, 1]);

# %%
X = df.drop(['Name', 'Platform','Genre', 'Publisher', 'Developer', 'Rating'], axis=1)
X['Year_of_Release'] = pd.factorize(X['Year_of_Release'], sort = True)[0]
X['User_Score'] = pd.factorize(X['User_Score'], sort = True)[0]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# %timeit a = list(range(100000)); b = list(range(100000))
tsne = TSNE(random_state=11)
tsne_representation = tsne.fit_transform(X_scaled)
# Out:
# 4.91 ms ± 227 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
plt.scatter(tsne_representation[:, 0], tsne_representation[:, 1]);

# %%
# не будет там ничего интересного.
plt.scatter(tsne_representation[:, 0], tsne_representation[:, 1], 
            c=df['User_Score'].map({0: 'blue', 1: 'orange'}));
