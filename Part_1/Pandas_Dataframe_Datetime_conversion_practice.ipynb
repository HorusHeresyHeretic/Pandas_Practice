# %%
import pandas as pd
df = pd.DataFrame({'year': [2015, 2016],
                       'month': [2, 3],
                       'day': [4, 5]})

# %%
df
# Out:
#    day  month  year
# 0    4      2  2015
# 1    5      3  2016

# %%
df = pd.DataFrame({'year': [2015, 2016, 2017],
                       'month': [2, 3,4],
                       'day': [4, 5,11]})

# %%
df
# Out:
#    day  month  year
# 0    4      2  2015
# 1    5      3  2016
# 2   11      4  2017

# %%
pd.to_datetime(df)
# Out:
# 0   2015-02-04
# 1   2016-03-05
# 2   2017-04-11
# dtype: datetime64[ns]

# %%
pd.to_datetime('13000101', format='%Y%m%d', errors='ignore')
# Out:
# datetime.datetime(1300, 1, 1, 0, 0)

# %%
df
# Out:
#    day  month  year
# 0    4      2  2015
# 1    5      3  2016
# 2   11      4  2017

# %%
pd.to_datetime(df)
# Out:
# 0   2015-02-04
# 1   2016-03-05
# 2   2017-04-11
# dtype: datetime64[ns]

# %%
data = pd.to_datetime(df)

# %%
data
# Out:
# 0   2015-02-04
# 1   2016-03-05
# 2   2017-04-11
# dtype: datetime64[ns]

# %%
s = pd.Series(['3/11/2000', '3/12/2000', '3/13/2000']*1000)

# %%
s.head()
# Out:
# 0    3/11/2000
# 1    3/12/2000
# 2    3/13/2000
# 3    3/11/2000
# 4    3/12/2000
# dtype: object

# %%
df = pd.DataFrame({'year': [2015, 2016, 2017],
                       'month': [2, 3,4],
                       'day': [4, 5,11]})

# %%
df
# Out:
#    day  month  year
# 0    4      2  2015
# 1    5      3  2016
# 2   11      4  2017

# %%
df[~(df == 2) & (df // 2 == 0) | (df // 6 != 0)]
# Out:
#     day  month  year
# 0   NaN    NaN  2015
# 1   NaN    NaN  2016
# 2  11.0    NaN  2017

# %%
df.dropna()
# Out:
#    day  month  year
# 0    4      2  2015
# 1    5      3  2016
# 2   11      4  2017

# %%
df2 = df[~(df == 2) & (df // 2 == 0) | (df // 6 != 0)]

# %%
df2
# Out:
#     day  month  year
# 0   NaN    NaN  2015
# 1   NaN    NaN  2016
# 2  11.0    NaN  2017

# %%
df2.dropna()
# Out:
# Empty DataFrame
# Columns: [day, month, year]
# Index: []

# %%
df = pd.DataFrame({'year': [2015, 2016, 2017],
                       'month': [2, 3,4],
                       'day': [4, 5,11]})

# %%
df2 = df[~(df == 2) & (df // 2 == 0) | (df // 6 != 0)]

# %%
df['deadline] = (df['year'] >= curr_year) & и т.д.).atype(int)

# %%
import pandas as pd
Deadline = pd.DataFrame({"source": ["name", "name", "Министерство_обороны","name","name",
                                    "name","name", "name", "name","name", "name", "name"],
                   "quest": ["name", "name", "Строительство_Варп_Портала","name","name",
                             "name","name", "name", "name","name", "name", "name"],
                   "order":["name", "name", "Федеральный_закон","name","name",
                            "name","name", "name", "name","name", "name", "name"],                   
                   "unit": ["name", "name", "Легионы_хаоса","name","name",
                            "name","name", "name", "name","name", "name", "name"],
                   "hero": ["name", "name", "Няшка_Хорус","name","name",
                            "name","name", "name", "name","name", "name", "name"],
                   "deadline": ["name", "name", "Вчера","name","name",
                                "name","name", "name", "name","name", "name", "name"],
                   'source_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'source_month': [2, 3,10,2,3,4,5,12,8,10,11,12],
                         'source_day': [4, 5,19,23,30,29,28,10,14,1,2,11],
                   'quest_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'quest_month': [2, 3,10,2,3,4,5,12,8,10,11,12], 
                         'quest_day': [4, 5,19,23,30,29,28,10,14,1,2,11],
                   'order_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'order_month': [2, 3,10,2,3,4,5,12,8,10,11,12],
                         'order_day': [4, 5,19,23,30,29,28,10,14,1,2,11],
                   'unit_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'unit_month': [2, 3,10,2,3,4,5,12,8,10,11,12], 
                         'unit_day': [2,5,19,23,30,29,28,10,14,1,2,11],
                   'hero_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'hero_month': [2, 3,10,2,3,4,5,12,8,10,11,12], 
                         'hero_day': [1,4,19,23,30,29,28,10,14,1,2,11],
                   'deadline_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'deadline_month': [2, 3,10,2,3,4,5,12,8,10,11,12],
                         'deadline_day': [4, 5,18,23,30,29,28,10,14,1,2,11],
                  })
Deadline = Deadline[['source','source_year','source_month','source_day',"quest",
                     'quest_year','quest_month','quest_day',"order",'order_year',
                     'order_month', 'order_day', "unit",'unit_year', 'unit_month',
                     'unit_day',"hero",'hero_year','hero_month','hero_day',"deadline",
                     'deadline_year','deadline_month','deadline_day']]
Deadline
# Out:
#                   source  source_year  source_month  source_day  \
# 0                   name         2015             2           4
# 1                   name         2016             3           5
# 2   Министерство_обороны         2017            10          19
# 3                   name         2011             2          23
# 4                   name         2017             3          30
# 5                   name         2017             4          29
# 6                   name         2011             5          28
# 7                   name         2014            12          10
# 8                   name         2011             8          14
# 9                   name         2022            10           1
# 10                  name         2009            11           2
# 11                  name         2021            12          11
#
#                          quest  quest_year  quest_month  quest_day  \
# ...

# %%
df['deadline'] = (df['year'] >= curr_year) & (df['month']>= curr_year & (df['day'] >= curr_year)).atype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-128cff80c0ae> in <module>()
# ----> 1 df['deadline'] = (df['year'] >= curr_year) & (df['month']>= curr_year & (df['day'] >= curr_year)).atype(int)
#
# NameError: name 'curr_year' is not defined

# %%
import datetime as dt     
date = dt.date.today
print(date)
# Out:
# <built-in method today of type object at 0x00000000575397B0>

# %%
date = dt.date.today()

# %%
date
# Out:
# datetime.date(2017, 10, 22)

# %%
curr_year = date

# %%
df['deadline'] = (df['year'] >= curr_year) & (df['month']>= curr_year & (df['day'] >= curr_year)).atype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-128cff80c0ae> in <module>()
# ----> 1 df['deadline'] = (df['year'] >= curr_year) & (df['month']>= curr_year & (df['day'] >= curr_year)).atype(int)
#
# J:\HiEnd\StandAloneComplex\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     859
#     860             with np.errstate(all='ignore'):
# --> 861                 res = na_op(values, other)
#     862             if is_scalar(res):
#     863                 raise TypeError('Could not compare %s type with Series' %
#
# J:\HiEnd\StandAloneComplex\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     796             try:
#     797                 with np.errstate(all='ignore'):
# --> 798                     result = getattr(x, name)(y)
#     799                 if result is NotImplemented:
# ...

# %%
df['deadline'] = (df['year'] > curr_year) & (df['month']> curr_year & (df['day'] > curr_year)).atype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-d609444a6244> in <module>()
# ----> 1 df['deadline'] = (df['year'] > curr_year) & (df['month']> curr_year & (df['day'] > curr_year)).atype(int)
#
# J:\HiEnd\StandAloneComplex\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     859
#     860             with np.errstate(all='ignore'):
# --> 861                 res = na_op(values, other)
#     862             if is_scalar(res):
#     863                 raise TypeError('Could not compare %s type with Series' %
#
# J:\HiEnd\StandAloneComplex\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     796             try:
#     797                 with np.errstate(all='ignore'):
# --> 798                     result = getattr(x, name)(y)
#     799                 if result is NotImplemented:
# ...

# %%
pd.to_datetime(df['year'])
# Out:
# 0   1970-01-01 00:00:00.000002015
# 1   1970-01-01 00:00:00.000002016
# 2   1970-01-01 00:00:00.000002017
# Name: year, dtype: datetime64[ns]

# %%
df['deadline'] = (df['year'] > curr_year) & (df['month']> curr_year & (df['day'] > curr_year)).atype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-d609444a6244> in <module>()
# ----> 1 df['deadline'] = (df['year'] > curr_year) & (df['month']> curr_year & (df['day'] > curr_year)).atype(int)
#
# J:\HiEnd\StandAloneComplex\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     859
#     860             with np.errstate(all='ignore'):
# --> 861                 res = na_op(values, other)
#     862             if is_scalar(res):
#     863                 raise TypeError('Could not compare %s type with Series' %
#
# J:\HiEnd\StandAloneComplex\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     796             try:
#     797                 with np.errstate(all='ignore'):
# --> 798                     result = getattr(x, name)(y)
#     799                 if result is NotImplemented:
# ...

# %%
pd.to_datetime(df['month'])
# Out:
# 0   1970-01-01 00:00:00.000000002
# 1   1970-01-01 00:00:00.000000003
# 2   1970-01-01 00:00:00.000000004
# Name: month, dtype: datetime64[ns]

# %%
pd.to_datetime(df['day'])
# Out:
# 0   1970-01-01 00:00:00.000000004
# 1   1970-01-01 00:00:00.000000005
# 2   1970-01-01 00:00:00.000000011
# Name: day, dtype: datetime64[ns]

# %%
df['deadline'] = (df['year'] > curr_year) & (df['month']> curr_year & (df['day'] > curr_year)).atype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-d609444a6244> in <module>()
# ----> 1 df['deadline'] = (df['year'] > curr_year) & (df['month']> curr_year & (df['day'] > curr_year)).atype(int)
#
# J:\HiEnd\StandAloneComplex\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     859
#     860             with np.errstate(all='ignore'):
# --> 861                 res = na_op(values, other)
#     862             if is_scalar(res):
#     863                 raise TypeError('Could not compare %s type with Series' %
#
# J:\HiEnd\StandAloneComplex\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     796             try:
#     797                 with np.errstate(all='ignore'):
# --> 798                     result = getattr(x, name)(y)
#     799                 if result is NotImplemented:
# ...

# %%
pd.to_datetime(df['year'],df['month'], df['day'] )
# Out:
# J:\HiEnd\StandAloneComplex\lib\site-packages\pandas\core\ops.py:798: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-1154292d64a5> in <module>()
# ----> 1 pd.to_datetime(df['year'],df['month'], df['day'] )
#
# J:\HiEnd\StandAloneComplex\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     507     elif isinstance(arg, ABCSeries):
#     508         from pandas import Series
# --> 509         values = _convert_listlike(arg._values, False, format)
#     510         result = Series(values, index=arg.index, name=arg.name)
#     511     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# ...

# %%
[In reply to Sadness is everything]
df['new col'] = df['col'].apply( сюда скармливаешь функцию возвращающую true/false )

Либо df['col'].map( словарь со значениями true/false)

Ну и логические операторы можно стакать
df[~(df == 2) & (df // 2 == 0) | (df // 6 != 0)]

Для удобства ещё обычно добавляют в конце .astype(int). Чтоб 0 и 1 было.

Если же ты про то откуда churn, то его руками размечают ассесоры, которые готовят данные.

написать Churn стоит денег Но часто используется обучение без учителя, 
где методами машинного обучения предсказывают категории. См. задачи кластеризации.

Ну тут я так понимаю что-то вида:
df['target'] = (df['deadline] & (df['year'] >= curr_year) & и т.д.).atype(int)
                   
Но лучше работать сразу с датой одной колонкой. Причем df['timestamp'].apply(pd.to_datetime)
                   
[In reply to Sadness is everything]
Да можно, тогда из того что выше будет:

zOmgwtfbbq:
Ну тут я так понимаю что-то вида:
df['deadline] = (df['year'] >= curr_year) & и т.д.).atype(int)
   
[In reply to Sadness is everything]
Тогда достаточно размечать связкой логических операторов через &. Но из постановки задачи рекомендую преобразовать 
   три столбца
в один типа datetime. Там много плюшек для работы со временем   
   
Можно сравнивать с now например

# %%
Deadline['deadline'] = pd.to_datetime(Deadline['deadline'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# J:\HiEnd\StandAloneComplex\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     443             try:
# --> 444                 values, tz = tslib.datetime_to_datetime64(arg)
#     445                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.datetime_to_datetime64 (pandas\_libs\tslib.c:33275)()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-74c272d6ae1a> in <module>()
# ----> 1 Deadline['deadline'] = pd.to_datetime(Deadline['deadline'])
#
# ...

# %%
Deadline
# Out:
#                   source  source_year  source_month  source_day  \
# 0                   name         2015             2           4
# 1                   name         2016             3           5
# 2   Министерство_обороны         2017            10          19
# 3                   name         2011             2          23
# 4                   name         2017             3          30
# 5                   name         2017             4          29
# 6                   name         2011             5          28
# 7                   name         2014            12          10
# 8                   name         2011             8          14
# 9                   name         2022            10           1
# 10                  name         2009            11           2
# 11                  name         2021            12          11
#
#                          quest  quest_year  quest_month  quest_day  \
# ...

# %%
Deadline['deadline'] = Deadline['deadline'].astype('datetime64[ns]')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-c3a6e9e63617> in <module>()
# ----> 1 Deadline['deadline'] = Deadline['deadline'].astype('datetime64[ns]')
#
# J:\HiEnd\StandAloneComplex\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# J:\HiEnd\StandAloneComplex\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3297         # else, only a single dtype is given
#    3298         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 3299                                      **kwargs)
#    3300         return self._constructor(new_data).__finalize__(self)
# ...

# %%
import datetime as dp
Deadline['deadline'] = pd.to_datetime(Deadline['deadline'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# J:\HiEnd\StandAloneComplex\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     443             try:
# --> 444                 values, tz = tslib.datetime_to_datetime64(arg)
#     445                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.datetime_to_datetime64 (pandas\_libs\tslib.c:33275)()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-99a55c08c563> in <module>()
#       1 import datetime as dp
# ----> 2 Deadline['deadline'] = pd.to_datetime(Deadline['deadline'])
#
# ...

# %%
import pandas as pd
Deadline = pd.DataFrame({"source": ["name", "name", "Министерство_обороны","name","name",
                                    "name","name", "name", "name","name", "name", "name"],
                   "quest": ["name", "name", "Строительство_Варп_Портала","name","name",
                             "name","name", "name", "name","name", "name", "name"],
                   "order":["name", "name", "Федеральный_закон","name","name",
                            "name","name", "name", "name","name", "name", "name"],                   
                   "unit": ["name", "name", "Легионы_хаоса","name","name",
                            "name","name", "name", "name","name", "name", "name"],
                   "hero": ["name", "name", "Няшка_Хорус","name","name",
                            "name","name", "name", "name","name", "name", "name"],
                   "deadline": [ True, True, True,False, False, False,
                                False, True, True, True, False, False],
                   'source_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'source_month': [2, 3,10,2,3,4,5,12,8,10,11,12],
                         'source_day': [4, 5,19,23,30,29,28,10,14,1,2,11],
                   'quest_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'quest_month': [2, 3,10,2,3,4,5,12,8,10,11,12], 
                         'quest_day': [4, 5,19,23,30,29,28,10,14,1,2,11],
                   'order_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'order_month': [2, 3,10,2,3,4,5,12,8,10,11,12],
                         'order_day': [4, 5,19,23,30,29,28,10,14,1,2,11],
                   'unit_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'unit_month': [2, 3,10,2,3,4,5,12,8,10,11,12], 
                         'unit_day': [2,5,19,23,30,29,28,10,14,1,2,11],
                   'hero_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'hero_month': [2, 3,10,2,3,4,5,12,8,10,11,12], 
                         'hero_day': [1,4,19,23,30,29,28,10,14,1,2,11],
                   'deadline_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'deadline_month': [2, 3,10,2,3,4,5,12,8,10,11,12],
                         'deadline_day': [4, 5,18,23,30,29,28,10,14,1,2,11],
                  })
Deadline = Deadline[['source','source_year','source_month','source_day',"quest",
                     'quest_year','quest_month','quest_day',"order",'order_year',
                     'order_month', 'order_day', "unit",'unit_year', 'unit_month',
                     'unit_day',"hero",'hero_year','hero_month','hero_day',"deadline",
                     'deadline_year','deadline_month','deadline_day']]
Deadline
# Out:
#                   source  source_year  source_month  source_day  \
# 0                   name         2015             2           4
# 1                   name         2016             3           5
# 2   Министерство_обороны         2017            10          19
# 3                   name         2011             2          23
# 4                   name         2017             3          30
# 5                   name         2017             4          29
# 6                   name         2011             5          28
# 7                   name         2014            12          10
# 8                   name         2011             8          14
# 9                   name         2022            10           1
# 10                  name         2009            11           2
# 11                  name         2021            12          11
#
#                          quest  quest_year  quest_month  quest_day  \
# ...

# %%
Deadline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 24 columns):
# source            12 non-null object
# source_year       12 non-null int64
# source_month      12 non-null int64
# source_day        12 non-null int64
# quest             12 non-null object
# quest_year        12 non-null int64
# quest_month       12 non-null int64
# quest_day         12 non-null int64
# order             12 non-null object
# order_year        12 non-null int64
# order_month       12 non-null int64
# order_day         12 non-null int64
# unit              12 non-null object
# unit_year         12 non-null int64
# unit_month        12 non-null int64
# unit_day          12 non-null int64
# hero              12 non-null object
# hero_year         12 non-null int64
# hero_month        12 non-null int64
# hero_day          12 non-null int64
# deadline          12 non-null bool
# deadline_year     12 non-null int64
# deadline_month    12 non-null int64
# ...

# %%
Deadline['deadline'] = Deadline["deadline"].astype("str")

# %%
Deadline
# Out:
#                   source  source_year  source_month  source_day  \
# 0                   name         2015             2           4
# 1                   name         2016             3           5
# 2   Министерство_обороны         2017            10          19
# 3                   name         2011             2          23
# 4                   name         2017             3          30
# 5                   name         2017             4          29
# 6                   name         2011             5          28
# 7                   name         2014            12          10
# 8                   name         2011             8          14
# 9                   name         2022            10           1
# 10                  name         2009            11           2
# 11                  name         2021            12          11
#
#                          quest  quest_year  quest_month  quest_day  \
# ...

# %%
Deadline['deadline'] = pd.to_datetime(Deadline['deadline'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# J:\HiEnd\StandAloneComplex\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     443             try:
# --> 444                 values, tz = tslib.datetime_to_datetime64(arg)
#     445                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.datetime_to_datetime64 (pandas\_libs\tslib.c:33275)()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-74c272d6ae1a> in <module>()
# ----> 1 Deadline['deadline'] = pd.to_datetime(Deadline['deadline'])
#
# ...

# %%
import pandas as pd
Deadline = pd.DataFrame({"source": ["name", "name", "Министерство_обороны","name","name",
                                    "name","name", "name", "name","name", "name", "name"],
                   "quest": ["name", "name", "Строительство_Варп_Портала","name","name",
                             "name","name", "name", "name","name", "name", "name"],
                   "order":["name", "name", "Федеральный_закон","name","name",
                            "name","name", "name", "name","name", "name", "name"],                   
                   "unit": ["name", "name", "Легионы_хаоса","name","name",
                            "name","name", "name", "name","name", "name", "name"],
                   "hero": ["name", "name", "Няшка_Хорус","name","name",
                            "name","name", "name", "name","name", "name", "name"],
                   "deadline": [ '2012-05-01', '2012-05-02', '2012-05-03','2012-05-01',
                                '2012-05-02', '2012-05-03','2012-05-01', '2012-05-02',
                                '2012-05-03','2012-05-01', '2012-05-02', '2012-05-03'],
                   'source_time': [ '2012-05-01', '2012-05-02', '2012-05-03','2012-05-01',
                                '2012-05-02', '2012-05-03','2012-05-01', '2012-05-02',
                                '2012-05-03','2012-05-01', '2012-05-02', '2012-05-03'],
                   'quest_time': [ '2012-05-01', '2012-05-02', '2012-05-03','2012-05-01',
                                '2012-05-02', '2012-05-03','2012-05-01', '2012-05-02',
                                '2012-05-03','2012-05-01', '2012-05-02', '2012-05-03'],
                   'order_time': [ '2012-05-01', '2012-05-02', '2012-05-03','2012-05-01',
                                '2012-05-02', '2012-05-03','2012-05-01', '2012-05-02',
                                '2012-05-03','2012-05-01', '2012-05-02', '2012-05-03'],
                   'unit_time': [ '2012-05-01', '2012-05-02', '2012-05-03','2012-05-01',
                                '2012-05-02', '2012-05-03','2012-05-01', '2012-05-02',
                                '2012-05-03','2012-05-01', '2012-05-02', '2012-05-03'],
                   'hero_time': [ '2012-05-01', '2012-05-02', '2012-05-03','2012-05-01',
                                '2012-05-02', '2012-05-03','2012-05-01', '2012-05-02',
                                '2012-05-03','2012-05-01', '2012-05-02', '2012-05-03'],
                   'deadline_time': [ '2012-05-01', '2012-05-02', '2012-05-03','2012-05-01',
                                '2012-05-02', '2012-05-03','2012-05-01', '2012-05-02',
                                '2012-05-03','2012-05-01', '2012-05-02', '2012-05-03'],
                  })

# %%
Deadline
# Out:
#       deadline deadline_year         hero   hero_time              order  \
# 0   2012-05-01    2012-05-01         name  2012-05-01               name
# 1   2012-05-02    2012-05-02         name  2012-05-02               name
# 2   2012-05-03    2012-05-03  Няшка_Хорус  2012-05-03  Федеральный_закон
# 3   2012-05-01    2012-05-01         name  2012-05-01               name
# 4   2012-05-02    2012-05-02         name  2012-05-02               name
# 5   2012-05-03    2012-05-03         name  2012-05-03               name
# 6   2012-05-01    2012-05-01         name  2012-05-01               name
# 7   2012-05-02    2012-05-02         name  2012-05-02               name
# 8   2012-05-03    2012-05-03         name  2012-05-03               name
# 9   2012-05-01    2012-05-01         name  2012-05-01               name
# 10  2012-05-02    2012-05-02         name  2012-05-02               name
# 11  2012-05-03    2012-05-03         name  2012-05-03               name
#
# ...

# %%
import pandas as pd
Deadline = pd.DataFrame({"source": ["name", "name", "Министерство_обороны","name","name",
                                    "name","name", "name", "name","name", "name", "name"],
                   "quest": ["name", "name", "Строительство_Варп_Портала","name","name",
                             "name","name", "name", "name","name", "name", "name"],
                   "order":["name", "name", "Федеральный_закон","name","name",
                            "name","name", "name", "name","name", "name", "name"],                   
                   "unit": ["name", "name", "Легионы_хаоса","name","name",
                            "name","name", "name", "name","name", "name", "name"],
                   "hero": ["name", "name", "Няшка_Хорус","name","name",
                            "name","name", "name", "name","name", "name", "name"],
                   "deadline": [ True, True, True,False, False, False,
                                False, True, True, True, False, False],
                   'source_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'source_month': [2, 3,10,2,3,4,5,12,8,10,11,12],
                         'source_day': [4, 5,19,23,30,29,28,10,14,1,2,11],
                   'quest_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'quest_month': [2, 3,10,2,3,4,5,12,8,10,11,12], 
                         'quest_day': [4, 5,19,23,30,29,28,10,14,1,2,11],
                   'order_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'order_month': [2, 3,10,2,3,4,5,12,8,10,11,12],
                         'order_day': [4, 5,19,23,30,29,28,10,14,1,2,11],
                   'unit_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'unit_month': [2, 3,10,2,3,4,5,12,8,10,11,12], 
                         'unit_day': [2,5,19,23,30,29,28,10,14,1,2,11],
                   'hero_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'hero_month': [2, 3,10,2,3,4,5,12,8,10,11,12], 
                         'hero_day': [1,4,19,23,30,29,28,10,14,1,2,11],
                   'deadline_year': [2015, 2016, 2017,2011, 2017,2017, 2011,2014,2011,2022,2009,2021],
                         'deadline_month': [2, 3,10,2,3,4,5,12,8,10,11,12],
                         'deadline_day': [4, 5,18,23,30,29,28,10,14,1,2,11],
                  })
Deadline = Deadline[['source','source_year','source_month','source_day',"quest",
                     'quest_year','quest_month','quest_day',"order",'order_year',
                     'order_month', 'order_day', "unit",'unit_year', 'unit_month',
                     'unit_day',"hero",'hero_year','hero_month','hero_day',"deadline",
                     'deadline_year','deadline_month','deadline_day']]
Deadline
# Out:
#                   source  source_year  source_month  source_day  \
# 0                   name         2015             2           4
# 1                   name         2016             3           5
# 2   Министерство_обороны         2017            10          19
# 3                   name         2011             2          23
# 4                   name         2017             3          30
# 5                   name         2017             4          29
# 6                   name         2011             5          28
# 7                   name         2014            12          10
# 8                   name         2011             8          14
# 9                   name         2022            10           1
# 10                  name         2009            11           2
# 11                  name         2021            12          11
#
#                          quest  quest_year  quest_month  quest_day  \
# ...

# %%
Deadline['deadline'] = pd.to_datetime(Deadline['deadline'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-74c272d6ae1a> in <module>()
# ----> 1 Deadline['deadline'] = pd.to_datetime(Deadline['deadline'])
#
# J:\HiEnd\StandAloneComplex\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     507     elif isinstance(arg, ABCSeries):
#     508         from pandas import Series
# --> 509         values = _convert_listlike(arg._values, False, format)
#     510         result = Series(values, index=arg.index, name=arg.name)
#     511     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# J:\HiEnd\StandAloneComplex\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     433                     dayfirst=dayfirst,
#     434                     yearfirst=yearfirst,
# ...

# %%
Deadline['deadline'] = Deadline['quest_year'].astype(str) + '-' + Deadline['quest_month'].astype(str) + '-' + Deadline['quest_day'].astype(str)

# %%
Deadline['deadline']
# Out:
# 0       2015-2-4
# 1       2016-3-5
# 2     2017-10-19
# 3      2011-2-23
# 4      2017-3-30
# 5      2017-4-29
# 6      2011-5-28
# 7     2014-12-10
# 8      2011-8-14
# 9      2022-10-1
# 10     2009-11-2
# 11    2021-12-11
# Name: deadline, dtype: object

# %%
Менее костыльно

df['time'] = df[['year', 'month', 'day']].apply(lambda x: '-'.join(x), axis=1)

Имена  столбцов соответсвенно можно заранее загнать в список и передавать его

# %%
Andrey, [21.10.17 22:05]

>>> a = ["hello", "world", "one"]
>>> b = "sadjefiwdsuhoneewlloasdk"
>>> any(x in b for x in a)
True

Бу, [21.10.17 22:34]
Где мой кустик

# %%
df['deadline'] = (df['year'] > curr_year) & (df['month']> curr_year & (df['day'] > curr_year)).atype(int)

# %%
Deadline['deadline'] = Deadline['quest_year'].astype(str) + '-' + Deadline['quest_month'].astype(str) + '-' + Deadline['quest_day'].astype(str)

# %%
Deadline['deadline']
# Out:
# 0       2015-2-4
# 1       2016-3-5
# 2     2017-10-19
# 3      2011-2-23
# 4      2017-3-30
# 5      2017-4-29
# 6      2011-5-28
# 7     2014-12-10
# 8      2011-8-14
# 9      2022-10-1
# 10     2009-11-2
# 11    2021-12-11
# Name: deadline, dtype: object

# %%
deadline['deadline'] = (deadline['year'] > curr_year) & (deadline['month']> curr_year & (deadline['day'] > curr_year)).atype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-74aaf95e2bb8> in <module>()
# ----> 1 deadline['deadline'] = (deadline['year'] > curr_year) & (deadline['month']> curr_year & (deadline['day'] > curr_year)).atype(int)
#
# NameError: name 'deadline' is not defined
