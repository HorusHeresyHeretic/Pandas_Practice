# %%
from __future__ import (absolute_import, division,
                        print_function, unicode_literals)
import warnings
warnings.simplefilter('ignore')
import pandas as pd
import numpy as pr
df = pd.read_csv("J:/HiEnd/mlcourse_open-master/mlcourse_open-master/data/telecom_churn.csv")

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
# State                     3333 non-null object
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null object
# Voice mail plan           3333 non-null object
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total day charge          3333 non-null float64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total eve charge          3333 non-null float64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total night charge        3333 non-null float64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Total intl charge         3333 non-null float64
# ...

# %%
# полезная фича дебажить линейные скрипты print(r.content)

# %%
import os
import zipfile

import requests
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("J:/11/785737230_T_ONTIME.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450017 entries, 0 to 450016
# Data columns (total 33 columns):
# FL_DATE                  450017 non-null object
# UNIQUE_CARRIER           450017 non-null object
# AIRLINE_ID               450017 non-null int64
# TAIL_NUM                 449378 non-null object
# FL_NUM                   450017 non-null int64
# ORIGIN_AIRPORT_ID        450017 non-null int64
# ORIGIN_AIRPORT_SEQ_ID    450017 non-null int64
# ORIGIN_CITY_MARKET_ID    450017 non-null int64
# ORIGIN                   450017 non-null object
# ORIGIN_CITY_NAME         450017 non-null object
# DEST_AIRPORT_ID          450017 non-null int64
# DEST_AIRPORT_SEQ_ID      450017 non-null int64
# DEST_CITY_MARKET_ID      450017 non-null int64
# DEST                     450017 non-null object
# DEST_CITY_NAME           450017 non-null object
# CRS_DEP_TIME             450017 non-null int64
# DEP_TIME                 441476 non-null float64
# ...

# %%
zf = zipfile.ZipFile("data/flights.csv.zip")
fp = zf.extract(zf.filelist[0].filename, path='data/')
df = pd.read_csv(fp, parse_dates=["FL_DATE"]).rename(columns=str.lower)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450017 entries, 0 to 450016
# Data columns (total 33 columns):
# fl_date                  450017 non-null datetime64[ns]
# unique_carrier           450017 non-null object
# airline_id               450017 non-null int64
# tail_num                 449378 non-null object
# fl_num                   450017 non-null int64
# origin_airport_id        450017 non-null int64
# origin_airport_seq_id    450017 non-null int64
# origin_city_market_id    450017 non-null int64
# origin                   450017 non-null object
# origin_city_name         450017 non-null object
# dest_airport_id          450017 non-null int64
# dest_airport_seq_id      450017 non-null int64
# dest_city_market_id      450017 non-null int64
# dest                     450017 non-null object
# dest_city_name           450017 non-null object
# crs_dep_time             450017 non-null int64
# dep_time                 441476 non-null float64
# ...

# %%
df.ix[10:15, ['fl_date', 'tail_num']]
# Out:
# J:\HiEnd\StandAloneComplex\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.
#       fl_date tail_num
# 10 2017-01-01   N756AA
# 11 2017-01-01   N807AA
# 12 2017-01-01   N755AA
# 13 2017-01-01   N951AA
# 14 2017-01-01   N523AA
# 15 2017-01-01   N155AA

# %%
first = df.groupby('airline_id')[['fl_date', 'unique_carrier']].first()
first.head()
# Out:
#               fl_date unique_carrier
# airline_id
# 19393      2017-01-01             WN
# 19690      2017-01-01             HA
# 19790      2017-01-01             DL
# 19805      2017-01-01             AA
# 19930      2017-01-01             AS

# %%
first.ix[10:15, ['fl_date', 'tail_num']]
# Out:
# J:\HiEnd\StandAloneComplex\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [fl_date, tail_num]
# Index: []

# %%
first = df.groupby('unique_carrier').first()
first.ix[10:15, ['fl_date', 'tail_num']]
# Out:
# J:\HiEnd\StandAloneComplex\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#                   fl_date tail_num
# unique_carrier
# VX             2017-01-01   N846VA
# WN             2017-01-01   N955WN

# %%
f = pd.DataFrame({'a':[1,2,3,4,5], 'b':[10,20,30,40,50]})
f
# Out:
#    a   b
# 0  1  10
# 1  2  20
# 2  3  30
# 3  4  40
# 4  5  50

# %%
with pd.option_context('mode.chained_assignment', None):
    f[f['a'] <= 3]['b'] = f[f['a'] <= 3 ]['b'] / 10
f
# Out:
#    a   b
# 0  1  10
# 1  2  20
# 2  3  30
# 3  4  40
# 4  5  50

# %%
f.loc[f['a'] <= 3, 'b'] = f.loc[f['a'] <= 3, 'b'] / 10
f
# Out:
#    a     b
# 0  1   1.0
# 1  2   2.0
# 2  3   3.0
# 3  4  40.0
# 4  5  50.0

# %%
df.head()
# Out:
#      fl_date unique_carrier  airline_id tail_num  fl_num  origin_airport_id  \
# 0 2017-01-01             AA       19805   N153AA    1766              13930
# 1 2017-01-01             AA       19805   N192AA    1767              12889
# 2 2017-01-01             AA       19805   N829AA    1768              11278
# 3 2017-01-01             AA       19805   N770AA    1769              15304
# 4 2017-01-01             AA       19805   N754AA    1770              14100
#
#    origin_airport_seq_id  origin_city_market_id origin  origin_city_name  \
# 0                1393004                  30977    ORD       Chicago, IL
# 1                1288903                  32211    LAS     Las Vegas, NV
# 2                1127803                  30852    DCA    Washington, DC
# 3                1530402                  33195    TPA         Tampa, FL
# 4                1410002                  34100    PHL  Philadelphia, PA
#
#       ...       arr_time  arr_delay  cancelled cancellation_code  \
# ...

# %%
anime = df
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450017 entries, 0 to 450016
# Data columns (total 33 columns):
# fl_date                  450017 non-null datetime64[ns]
# unique_carrier           450017 non-null object
# airline_id               450017 non-null int64
# tail_num                 449378 non-null object
# fl_num                   450017 non-null int64
# origin_airport_id        450017 non-null int64
# origin_airport_seq_id    450017 non-null int64
# origin_city_market_id    450017 non-null int64
# origin                   450017 non-null object
# origin_city_name         450017 non-null object
# dest_airport_id          450017 non-null int64
# dest_airport_seq_id      450017 non-null int64
# dest_city_market_id      450017 non-null int64
# dest                     450017 non-null object
# dest_city_name           450017 non-null object
# crs_dep_time             450017 non-null int64
# dep_time                 441476 non-null float64
# ...

# %%
anime.loc[anime['arr_time']] > 1000
# Out:
#         fl_date  unique_carrier  airline_id  tail_num  fl_num  \
# 932.0      True            True        True      True    True
# 1717.0     True            True        True      True   False
# 1253.0     True            True        True      True    True
# 818.0      True            True        True      True    True
# 1305.0     True            True        True      True    True
# 824.0      True            True        True      True    True
# 1116.0     True            True        True      True   False
# 5.0        True            True        True      True    True
# 1830.0     True            True        True      True   False
# 1504.0     True            True        True      True   False
# 2031.0     True            True        True      True    True
# 1741.0     True            True        True      True   False
# 846.0      True            True        True      True    True
# 1030.0     True            True        True      True    True
# ...

# %%
anime.head()
# Out:
#      fl_date unique_carrier  airline_id tail_num  fl_num  origin_airport_id  \
# 0 2017-01-01             AA       19805   N153AA    1766              13930
# 1 2017-01-01             AA       19805   N192AA    1767              12889
# 2 2017-01-01             AA       19805   N829AA    1768              11278
# 3 2017-01-01             AA       19805   N770AA    1769              15304
# 4 2017-01-01             AA       19805   N754AA    1770              14100
#
#    origin_airport_seq_id  origin_city_market_id origin  origin_city_name  \
# 0                1393004                  30977    ORD       Chicago, IL
# 1                1288903                  32211    LAS     Las Vegas, NV
# 2                1127803                  30852    DCA    Washington, DC
# 3                1530402                  33195    TPA         Tampa, FL
# 4                1410002                  34100    PHL  Philadelphia, PA
#
#       ...       arr_time  arr_delay  cancelled cancellation_code  \
# ...

# %%
df[P(df['Name'])]

df[df['Churn'] == 1]

anime.loc[anime['arr_time']] > 1000

# %%
anime[anime['arr_time'] > 1000]
# Out:
#           fl_date unique_carrier  airline_id tail_num  fl_num  \
# 1      2017-01-01             AA       19805   N192AA    1767
# 2      2017-01-01             AA       19805   N829AA    1768
# 4      2017-01-01             AA       19805   N754AA    1770
# 6      2017-01-01             AA       19805   N585AA    1772
# 8      2017-01-01             AA       19805   N552AA    1775
# 9      2017-01-01             AA       19805   N581AA    1775
# 10     2017-01-01             AA       19805   N756AA    1776
# 11     2017-01-01             AA       19805   N807AA    1776
# 13     2017-01-01             AA       19805   N951AA    1782
# 14     2017-01-01             AA       19805   N523AA    1783
# 15     2017-01-01             AA       19805   N155AA    1783
# 16     2017-01-01             AA       19805   N753AA    1785
# 17     2017-01-01             AA       19805   N753AA    1785
# 18     2017-01-01             AA       19805   N202AA    1786
# ...

# %%
бинго блять!

# %%
hdf = df.set_index(['unique_carrier', 'origin', 'dest', 'tail_num',
                    'fl_date']).sort_index()
hdf[hdf.columns[:4]].head()
# Out:
#                                                 airline_id  fl_num  \
# unique_carrier origin dest tail_num fl_date
# AA             ABQ    DFW  N3ABAA   2017-01-15       19805    2611
#                                     2017-01-29       19805    1282
#                            N3AEAA   2017-01-11       19805    2511
#                            N3AJAA   2017-01-24       19805    2511
#                            N3AVAA   2017-01-11       19805    1282
#
#                                                 origin_airport_id  \
# unique_carrier origin dest tail_num fl_date
# AA             ABQ    DFW  N3ABAA   2017-01-15              10140
#                                     2017-01-29              10140
#                            N3AEAA   2017-01-11              10140
#                            N3AJAA   2017-01-24              10140
#                            N3AVAA   2017-01-11              10140
#
#                                                 origin_airport_seq_id
# ...

# %%
hdf1 = df.set_index(['origin_city_name', 'origin', 'dest', 'tail_num',
                    'fl_date']).sort_index()
hdf1[hdf1.columns[:4]].head()
# Out:
#                                                  unique_carrier  airline_id  \
# origin_city_name origin dest tail_num fl_date
# Aberdeen, SD     ABR    MSP  N426SW   2017-01-17             OO       20304
#                              N429SW   2017-01-02             OO       20304
#                              N431SW   2017-01-31             OO       20304
#                              N433SW   2017-01-19             OO       20304
#                              N441SW   2017-01-21             OO       20304
#
#                                                   fl_num  origin_airport_id
# origin_city_name origin dest tail_num fl_date
# Aberdeen, SD     ABR    MSP  N426SW   2017-01-17    7363              10141
#                              N429SW   2017-01-02    7363              10141
#                              N431SW   2017-01-31    7363              10141
#                              N433SW   2017-01-19    7365              10141
# ...

# %%
hdf2 = df.set_index(['origin_city_name']).sort_index()
hdf2[hdf2.columns[:4]].head()
# Out:
#                     fl_date unique_carrier  airline_id tail_num
# origin_city_name
# Aberdeen, SD     2017-01-19             OO       20304   N433SW
# Aberdeen, SD     2017-01-18             OO       20304   N699BR
# Aberdeen, SD     2017-01-08             OO       20304   N442SW
# Aberdeen, SD     2017-01-27             OO       20304   N910EV
# Aberdeen, SD     2017-01-25             OO       20304   N868CA

# %%
hdf2 = df.set_index(['origin_city_name']).sort_index()
hdf2[hdf2.columns[:7]].head()
# Out:
#                     fl_date unique_carrier  airline_id tail_num  fl_num  \
# origin_city_name
# Aberdeen, SD     2017-01-19             OO       20304   N433SW    7365
# Aberdeen, SD     2017-01-18             OO       20304   N699BR    7363
# Aberdeen, SD     2017-01-08             OO       20304   N442SW    7365
# Aberdeen, SD     2017-01-27             OO       20304   N910EV    7363
# Aberdeen, SD     2017-01-25             OO       20304   N868CA    7363
#
#                   origin_airport_id  origin_airport_seq_id
# origin_city_name
# Aberdeen, SD                  10141                1014103
# Aberdeen, SD                  10141                1014103
# Aberdeen, SD                  10141                1014103
# Aberdeen, SD                  10141                1014103
# Aberdeen, SD                  10141                1014103

# %%
hdf.loc[['AA', 'DL', 'US'], ['dep_time', 'dep_delay']]
# Out:
#                                                 dep_time  dep_delay
# unique_carrier origin dest tail_num fl_date
# AA             ABQ    DFW  N3ABAA   2017-01-15     500.0        0.0
#                                     2017-01-29     757.0       -3.0
#                            N3AEAA   2017-01-11    1451.0       -9.0
#                            N3AJAA   2017-01-24    1502.0        2.0
#                            N3AVAA   2017-01-11     752.0       -8.0
#                            N3AWAA   2017-01-27    1550.0       50.0
#                            N3AXAA   2017-01-16    1524.0       24.0
#                                     2017-01-17     757.0       -3.0
#                            N3BJAA   2017-01-25     823.0       23.0
#                            N3BPAA   2017-01-11    1638.0       -7.0
#                            N3BTAA   2017-01-26     753.0       -7.0
#                            N3BYAA   2017-01-18    1452.0       -8.0
# ...

# %%
hdf.loc[(['AA', 'DL', 'US'], ['ORD', 'DSM']), ['dep_time', 'dep_delay']]
# Out:
#                                                 dep_time  dep_delay
# unique_carrier origin dest tail_num fl_date
# AA             DSM    DFW  N424AA   2017-01-23    1324.0       -3.0
#                            N426AA   2017-01-25     541.0       -9.0
#                            N437AA   2017-01-13     542.0       -8.0
#                                     2017-01-23     544.0       -6.0
#                            N438AA   2017-01-11     542.0       -8.0
#                            N439AA   2017-01-24     544.0       -6.0
#                                     2017-01-31     544.0       -6.0
#                            N4UBAA   2017-01-18    1323.0       -4.0
#                            N4WNAA   2017-01-27    1322.0       -5.0
#                            N4XBAA   2017-01-09     536.0      -14.0
#                            N4XEAA   2017-01-21     544.0       -6.0
#                            N4XFAA   2017-01-31    1320.0       -7.0
# ...

# %%
hdf2.loc[['Aberdeen, SD'], ['origin_airport_id']].head()
# Out:
#                   origin_airport_id
# origin_city_name
# Aberdeen, SD                  10141
# Aberdeen, SD                  10141
# Aberdeen, SD                  10141
# Aberdeen, SD                  10141
# Aberdeen, SD                  10141

# %%
hdf.loc[pd.IndexSlice[:, ['ORD', 'DSM']], ['dep_time', 'dep_delay']]
# Out:
#                                                 dep_time  dep_delay
# unique_carrier origin dest tail_num fl_date
# AA             DSM    DFW  N424AA   2017-01-23    1324.0       -3.0
#                            N426AA   2017-01-25     541.0       -9.0
#                            N437AA   2017-01-13     542.0       -8.0
#                                     2017-01-23     544.0       -6.0
#                            N438AA   2017-01-11     542.0       -8.0
#                            N439AA   2017-01-24     544.0       -6.0
#                                     2017-01-31     544.0       -6.0
#                            N4UBAA   2017-01-18    1323.0       -4.0
#                            N4WNAA   2017-01-27    1322.0       -5.0
#                            N4XBAA   2017-01-09     536.0      -14.0
#                            N4XEAA   2017-01-21     544.0       -6.0
#                            N4XFAA   2017-01-31    1320.0       -7.0
# ...

# %%
pd.IndexSlice[:, ['ORD', 'DSM']]
# Out:
# (slice(None, None, None), ['ORD', 'DSM'])

# %%
hdf.head()
# Out:
#                                                 airline_id  fl_num  \
# unique_carrier origin dest tail_num fl_date
# AA             ABQ    DFW  N3ABAA   2017-01-15       19805    2611
#                                     2017-01-29       19805    1282
#                            N3AEAA   2017-01-11       19805    2511
#                            N3AJAA   2017-01-24       19805    2511
#                            N3AVAA   2017-01-11       19805    1282
#
#                                                 origin_airport_id  \
# unique_carrier origin dest tail_num fl_date
# AA             ABQ    DFW  N3ABAA   2017-01-15              10140
#                                     2017-01-29              10140
#                            N3AEAA   2017-01-11              10140
#                            N3AJAA   2017-01-24              10140
#                            N3AVAA   2017-01-11              10140
#
#                                                 origin_airport_seq_id  \
# ...

# %%
anime
# Out:
#           fl_date unique_carrier  airline_id tail_num  fl_num  \
# 0      2017-01-01             AA       19805   N153AA    1766
# 1      2017-01-01             AA       19805   N192AA    1767
# 2      2017-01-01             AA       19805   N829AA    1768
# 3      2017-01-01             AA       19805   N770AA    1769
# 4      2017-01-01             AA       19805   N754AA    1770
# 5      2017-01-01             AA       19805   N754AA    1770
# 6      2017-01-01             AA       19805   N585AA    1772
# 7      2017-01-01             AA       19805   N737AA    1774
# 8      2017-01-01             AA       19805   N552AA    1775
# 9      2017-01-01             AA       19805   N581AA    1775
# 10     2017-01-01             AA       19805   N756AA    1776
# 11     2017-01-01             AA       19805   N807AA    1776
# 12     2017-01-01             AA       19805   N755AA    1780
# 13     2017-01-01             AA       19805   N951AA    1782
# ...

# %%
anime
# Out:
#           fl_date unique_carrier  airline_id tail_num  fl_num  \
# 0      2017-01-01             AA       19805   N153AA    1766
# 1      2017-01-01             AA       19805   N192AA    1767
# 2      2017-01-01             AA       19805   N829AA    1768
# 3      2017-01-01             AA       19805   N770AA    1769
# 4      2017-01-01             AA       19805   N754AA    1770
# 5      2017-01-01             AA       19805   N754AA    1770
# 6      2017-01-01             AA       19805   N585AA    1772
# 7      2017-01-01             AA       19805   N737AA    1774
# 8      2017-01-01             AA       19805   N552AA    1775
# 9      2017-01-01             AA       19805   N581AA    1775
# 10     2017-01-01             AA       19805   N756AA    1776
# 11     2017-01-01             AA       19805   N807AA    1776
# 12     2017-01-01             AA       19805   N755AA    1780
# 13     2017-01-01             AA       19805   N951AA    1782
# ...

# %%
anime.loc[anime['arr_time'] > 1000, 'arr_delay'] = anime.loc[anime['arr_time'] > 1000, 'arr_delay']

# %%
anime
# Out:
#           fl_date unique_carrier  airline_id tail_num  fl_num  \
# 0      2017-01-01             AA       19805   N153AA    1766
# 1      2017-01-01             AA       19805   N192AA    1767
# 2      2017-01-01             AA       19805   N829AA    1768
# 3      2017-01-01             AA       19805   N770AA    1769
# 4      2017-01-01             AA       19805   N754AA    1770
# 5      2017-01-01             AA       19805   N754AA    1770
# 6      2017-01-01             AA       19805   N585AA    1772
# 7      2017-01-01             AA       19805   N737AA    1774
# 8      2017-01-01             AA       19805   N552AA    1775
# 9      2017-01-01             AA       19805   N581AA    1775
# 10     2017-01-01             AA       19805   N756AA    1776
# 11     2017-01-01             AA       19805   N807AA    1776
# 12     2017-01-01             AA       19805   N755AA    1780
# 13     2017-01-01             AA       19805   N951AA    1782
# ...

# %%
anime.loc[anime['arr_time']] > 1000
# Out:
#         fl_date  unique_carrier  airline_id  tail_num  fl_num  \
# 932.0      True            True        True      True    True
# 1717.0     True            True        True      True   False
# 1253.0     True            True        True      True    True
# 818.0      True            True        True      True    True
# 1305.0     True            True        True      True    True
# 824.0      True            True        True      True    True
# 1116.0     True            True        True      True   False
# 5.0        True            True        True      True    True
# 1830.0     True            True        True      True   False
# 1504.0     True            True        True      True   False
# 2031.0     True            True        True      True    True
# 1741.0     True            True        True      True   False
# 846.0      True            True        True      True    True
# 1030.0     True            True        True      True    True
# ...

# %%
anime
# Out:
#           fl_date unique_carrier  airline_id tail_num  fl_num  \
# 0      2017-01-01             AA       19805   N153AA    1766
# 1      2017-01-01             AA       19805   N192AA    1767
# 2      2017-01-01             AA       19805   N829AA    1768
# 3      2017-01-01             AA       19805   N770AA    1769
# 4      2017-01-01             AA       19805   N754AA    1770
# 5      2017-01-01             AA       19805   N754AA    1770
# 6      2017-01-01             AA       19805   N585AA    1772
# 7      2017-01-01             AA       19805   N737AA    1774
# 8      2017-01-01             AA       19805   N552AA    1775
# 9      2017-01-01             AA       19805   N581AA    1775
# 10     2017-01-01             AA       19805   N756AA    1776
# 11     2017-01-01             AA       19805   N807AA    1776
# 12     2017-01-01             AA       19805   N755AA    1780
# 13     2017-01-01             AA       19805   N951AA    1782
# ...

# %%
af = anime.loc[anime['arr_time']] > 1000

# %%
af.head()
# Out:
#         fl_date  unique_carrier  airline_id  tail_num  fl_num  \
# 932.0      True            True        True      True    True
# 1717.0     True            True        True      True   False
# 1253.0     True            True        True      True    True
# 818.0      True            True        True      True    True
# 1305.0     True            True        True      True    True
#
#         origin_airport_id  origin_airport_seq_id  origin_city_market_id  \
# 932.0                True                   True                   True
# 1717.0               True                   True                   True
# 1253.0               True                   True                   True
# 818.0                True                   True                   True
# 1305.0               True                   True                   True
#
#         origin  origin_city_name     ...       arr_time  arr_delay  cancelled  \
# ...

# %%
# бинго блять.

# %%
ad = af.copy(deep=True)
ad.head()
# Out:
#         fl_date  unique_carrier  airline_id  tail_num  fl_num  \
# 932.0      True            True        True      True    True
# 1717.0     True            True        True      True   False
# 1253.0     True            True        True      True    True
# 818.0      True            True        True      True    True
# 1305.0     True            True        True      True    True
#
#         origin_airport_id  origin_airport_seq_id  origin_city_market_id  \
# 932.0                True                   True                   True
# 1717.0               True                   True                   True
# 1253.0               True                   True                   True
# 818.0                True                   True                   True
# 1305.0               True                   True                   True
#
#         origin  origin_city_name     ...       arr_time  arr_delay  cancelled  \
# ...

# %%
pd.melt(ad, id_vars=['arr_time'], value_vars=['True', 'False'])
# Out:
#         arr_time variable  value
# 0           True     True    NaN
# 1           True     True    NaN
# 2           True     True    NaN
# 3           True     True    NaN
# 4           True     True    NaN
# 5           True     True    NaN
# 6           True     True    NaN
# 7          False     True    NaN
# 8           True     True    NaN
# 9           True     True    NaN
# 10          True     True    NaN
# 11          True     True    NaN
# 12         False     True    NaN
# 13          True     True    NaN
# 14          True     True    NaN
# 15          True     True    NaN
# 16         False     True    NaN
# 17         False     True    NaN
# 18         False     True    NaN
# 19          True     True    NaN
# 20          True     True    NaN
# 21          True     True    NaN
# 22          True     True    NaN
# 23          True     True    NaN
# 24          True     True    NaN
# 25          True     True    NaN
# 26          True     True    NaN
# ...

# %%
ad.head()
# Out:
#         fl_date  unique_carrier  airline_id  tail_num  fl_num  \
# 932.0      True            True        True      True    True
# 1717.0     True            True        True      True   False
# 1253.0     True            True        True      True    True
# 818.0      True            True        True      True    True
# 1305.0     True            True        True      True    True
#
#         origin_airport_id  origin_airport_seq_id  origin_city_market_id  \
# 932.0                True                   True                   True
# 1717.0               True                   True                   True
# 1253.0               True                   True                   True
# 818.0                True                   True                   True
# 1305.0               True                   True                   True
#
#         origin  origin_city_name     ...       arr_time  arr_delay  cancelled  \
# ...

# %%
pd.melt(ad, id_vars=['arr_time'], value_vars=['late_aircraft_delay', 'late_aircraft_delay'])
# Out:
#         arr_time             variable  value
# 0           True  late_aircraft_delay  False
# 1           True  late_aircraft_delay  False
# 2           True  late_aircraft_delay  False
# 3           True  late_aircraft_delay  False
# 4           True  late_aircraft_delay  False
# 5           True  late_aircraft_delay  False
# 6           True  late_aircraft_delay  False
# 7          False  late_aircraft_delay  False
# 8           True  late_aircraft_delay  False
# 9           True  late_aircraft_delay  False
# 10          True  late_aircraft_delay  False
# 11          True  late_aircraft_delay  False
# 12         False  late_aircraft_delay  False
# 13          True  late_aircraft_delay  False
# 14          True  late_aircraft_delay  False
# 15          True  late_aircraft_delay  False
# 16         False  late_aircraft_delay  False
# 17         False  late_aircraft_delay  False
# 18         False  late_aircraft_delay  False
# 19          True  late_aircraft_delay  False
# ...

# %%
ad.head()
# Out:
#         fl_date  unique_carrier  airline_id  tail_num  fl_num  \
# 932.0      True            True        True      True    True
# 1717.0     True            True        True      True   False
# 1253.0     True            True        True      True    True
# 818.0      True            True        True      True    True
# 1305.0     True            True        True      True    True
#
#         origin_airport_id  origin_airport_seq_id  origin_city_market_id  \
# 932.0                True                   True                   True
# 1717.0               True                   True                   True
# 1253.0               True                   True                   True
# 818.0                True                   True                   True
# 1305.0               True                   True                   True
#
#         origin  origin_city_name     ...       arr_time  arr_delay  cancelled  \
# ...

# %%
zone = pd.melt(ad, id_vars=['arr_time'], value_vars=['late_aircraft_delay', 'late_aircraft_delay'])

# %%
zone.head()
# Out:
#    arr_time             variable  value
# 0      True  late_aircraft_delay  False
# 1      True  late_aircraft_delay  False
# 2      True  late_aircraft_delay  False
# 3      True  late_aircraft_delay  False
# 4      True  late_aircraft_delay  False

# %%
type(zone)
# Out:
# pandas.core.frame.DataFrame

# %%
zone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900034 entries, 0 to 900033
# Data columns (total 3 columns):
# arr_time    900034 non-null bool
# variable    900034 non-null object
# value       900034 non-null bool
# dtypes: bool(2), object(1)
# memory usage: 8.6+ MB

# %%
ad.head()
# Out:
#         fl_date  unique_carrier  airline_id  tail_num  fl_num  \
# 932.0      True            True        True      True    True
# 1717.0     True            True        True      True   False
# 1253.0     True            True        True      True    True
# 818.0      True            True        True      True    True
# 1305.0     True            True        True      True    True
#
#         origin_airport_id  origin_airport_seq_id  origin_city_market_id  \
# 932.0                True                   True                   True
# 1717.0               True                   True                   True
# 1253.0               True                   True                   True
# 818.0                True                   True                   True
# 1305.0               True                   True                   True
#
#         origin  origin_city_name     ...       arr_time  arr_delay  cancelled  \
# ...

# %%
zone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900034 entries, 0 to 900033
# Data columns (total 3 columns):
# arr_time    900034 non-null bool
# variable    900034 non-null object
# value       900034 non-null bool
# dtypes: bool(2), object(1)
# memory usage: 8.6+ MB

# %%
zone.head()
# Out:
#    arr_time             variable  value
# 0      True  late_aircraft_delay  False
# 1      True  late_aircraft_delay  False
# 2      True  late_aircraft_delay  False
# 3      True  late_aircraft_delay  False
# 4      True  late_aircraft_delay  False

# %%
time = zone.copy(deep=True)

# %%
time
# Out:
#         arr_time             variable  value
# 0           True  late_aircraft_delay  False
# 1           True  late_aircraft_delay  False
# 2           True  late_aircraft_delay  False
# 3           True  late_aircraft_delay  False
# 4           True  late_aircraft_delay  False
# 5           True  late_aircraft_delay  False
# 6           True  late_aircraft_delay  False
# 7          False  late_aircraft_delay  False
# 8           True  late_aircraft_delay  False
# 9           True  late_aircraft_delay  False
# 10          True  late_aircraft_delay  False
# 11          True  late_aircraft_delay  False
# 12         False  late_aircraft_delay  False
# 13          True  late_aircraft_delay  False
# 14          True  late_aircraft_delay  False
# 15          True  late_aircraft_delay  False
# 16         False  late_aircraft_delay  False
# 17         False  late_aircraft_delay  False
# 18         False  late_aircraft_delay  False
# 19          True  late_aircraft_delay  False
# ...

# %%
time.drop(['variable'], axis='columns')
# Out:
#         arr_time  value
# 0           True  False
# 1           True  False
# 2           True  False
# 3           True  False
# 4           True  False
# 5           True  False
# 6           True  False
# 7          False  False
# 8           True  False
# 9           True  False
# 10          True  False
# 11          True  False
# 12         False  False
# 13          True  False
# 14          True  False
# 15          True  False
# 16         False  False
# 17         False  False
# 18         False  False
# 19          True  False
# 20          True  False
# 21          True  False
# 22          True  False
# 23          True  False
# 24          True  False
# 25          True  False
# 26          True  False
# 27          True  False
# 28          True  False
# 29          True  False
# ...          ...    ...
# 900004      True  False
# 900005     False  False
# 900006      True  False
# 900007      True  False
# 900008      True  False
# 900009      True  False
# ...

# %%
time.drop(['value', 'variable' ], axis='columns')
# Out:
#         arr_time             variable
# 0           True  late_aircraft_delay
# 1           True  late_aircraft_delay
# 2           True  late_aircraft_delay
# 3           True  late_aircraft_delay
# 4           True  late_aircraft_delay
# 5           True  late_aircraft_delay
# 6           True  late_aircraft_delay
# 7          False  late_aircraft_delay
# 8           True  late_aircraft_delay
# 9           True  late_aircraft_delay
# 10          True  late_aircraft_delay
# 11          True  late_aircraft_delay
# 12         False  late_aircraft_delay
# 13          True  late_aircraft_delay
# 14          True  late_aircraft_delay
# 15          True  late_aircraft_delay
# 16         False  late_aircraft_delay
# 17         False  late_aircraft_delay
# 18         False  late_aircraft_delay
# 19          True  late_aircraft_delay
# 20          True  late_aircraft_delay
# 21          True  late_aircraft_delay
# 22          True  late_aircraft_delay
# 23          True  late_aircraft_delay
# ...

# %%
time.head()
# Out:
#    arr_time             variable  value
# 0      True  late_aircraft_delay  False
# 1      True  late_aircraft_delay  False
# 2      True  late_aircraft_delay  False
# 3      True  late_aircraft_delay  False
# 4      True  late_aircraft_delay  False

# %%
time.drop(['value', 'variable' ], axis='columns')
# Out:
#         arr_time
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# 5           True
# 6           True
# 7          False
# 8           True
# 9           True
# 10          True
# 11          True
# 12         False
# 13          True
# 14          True
# 15          True
# 16         False
# 17         False
# 18         False
# 19          True
# 20          True
# 21          True
# 22          True
# 23          True
# 24          True
# 25          True
# 26          True
# 27          True
# 28          True
# 29          True
# ...          ...
# 900004      True
# 900005     False
# 900006      True
# 900007      True
# 900008      True
# 900009      True
# 900010      True
# 900011      True
# 900012     False
# 900013      True
# 900014      True
# 900015      True
# 900016      True
# 900017      True
# 900018      True
# 900019     False
# 900020      True
# 900021      True
# 900022     False
# 900023      True
# ...

# %%
the_time = time.drop(['value', 'variable' ], axis='columns')

# %%
the_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900034 entries, 0 to 900033
# Data columns (total 1 columns):
# arr_time    900034 non-null bool
# dtypes: bool(1)
# memory usage: 879.0 KB

# %%
the_time.head()
# Out:
#    arr_time
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True

# %%
anime.head()
# Out:
#      fl_date unique_carrier  airline_id tail_num  fl_num  origin_airport_id  \
# 0 2017-01-01             AA       19805   N153AA    1766              13930
# 1 2017-01-01             AA       19805   N192AA    1767              12889
# 2 2017-01-01             AA       19805   N829AA    1768              11278
# 3 2017-01-01             AA       19805   N770AA    1769              15304
# 4 2017-01-01             AA       19805   N754AA    1770              14100
#
#    origin_airport_seq_id  origin_city_market_id origin  origin_city_name  \
# 0                1393004                  30977    ORD       Chicago, IL
# 1                1288903                  32211    LAS     Las Vegas, NV
# 2                1127803                  30852    DCA    Washington, DC
# 3                1530402                  33195    TPA         Tampa, FL
# 4                1410002                  34100    PHL  Philadelphia, PA
#
#       ...       arr_time  arr_delay  cancelled cancellation_code  \
# ...

# %%
anime['arr_time'] = the_time["arr_time"]
anime.head()
# Out:
#      fl_date unique_carrier  airline_id tail_num  fl_num  origin_airport_id  \
# 0 2017-01-01             AA       19805   N153AA    1766              13930
# 1 2017-01-01             AA       19805   N192AA    1767              12889
# 2 2017-01-01             AA       19805   N829AA    1768              11278
# 3 2017-01-01             AA       19805   N770AA    1769              15304
# 4 2017-01-01             AA       19805   N754AA    1770              14100
#
#    origin_airport_seq_id  origin_city_market_id origin  origin_city_name  \
# 0                1393004                  30977    ORD       Chicago, IL
# 1                1288903                  32211    LAS     Las Vegas, NV
# 2                1127803                  30852    DCA    Washington, DC
# 3                1530402                  33195    TPA         Tampa, FL
# 4                1410002                  34100    PHL  Philadelphia, PA
#
#       ...       arr_time  arr_delay  cancelled cancellation_code  \
# ...

# %%
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450017 entries, 0 to 450016
# Data columns (total 33 columns):
# fl_date                  450017 non-null datetime64[ns]
# unique_carrier           450017 non-null object
# airline_id               450017 non-null int64
# tail_num                 449378 non-null object
# fl_num                   450017 non-null int64
# origin_airport_id        450017 non-null int64
# origin_airport_seq_id    450017 non-null int64
# origin_city_market_id    450017 non-null int64
# origin                   450017 non-null object
# origin_city_name         450017 non-null object
# dest_airport_id          450017 non-null int64
# dest_airport_seq_id      450017 non-null int64
# dest_city_market_id      450017 non-null int64
# dest                     450017 non-null object
# dest_city_name           450017 non-null object
# crs_dep_time             450017 non-null int64
# dep_time                 441476 non-null float64
# ...

# %%
anime.to_csv('animebool.csv')

# %%
df = pd.read_csv("C:/Users/Battlestation/animebool.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450017 entries, 0 to 450016
# Data columns (total 34 columns):
# Unnamed: 0               450017 non-null int64
# fl_date                  450017 non-null object
# unique_carrier           450017 non-null object
# airline_id               450017 non-null int64
# tail_num                 449378 non-null object
# fl_num                   450017 non-null int64
# origin_airport_id        450017 non-null int64
# origin_airport_seq_id    450017 non-null int64
# origin_city_market_id    450017 non-null int64
# origin                   450017 non-null object
# origin_city_name         450017 non-null object
# dest_airport_id          450017 non-null int64
# dest_airport_seq_id      450017 non-null int64
# dest_city_market_id      450017 non-null int64
# dest                     450017 non-null object
# dest_city_name           450017 non-null object
# crs_dep_time             450017 non-null int64
# ...
